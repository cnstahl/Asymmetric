# %%
import quantum as qm
import asymmetric as asym
import importlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
importlib.reload(asym)
# Out:
# <module 'asymmetric' from '/Users/cstahl/Documents/Senior/Thesis/python/Hamiltonian/asymmetric.py'>

# %%
L = 9
# Total time elapsed
end = 3
# Time steps per second
n = 20

weightfore9, weightback9 = asym.get_all_weights(L, end, n, here=False, dense = True)

# %%
end = (int) (n*3)

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightfore9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightback9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

# %%
# %run -p timeAsymmetric.py

# %%
shape = np.zeros((3,4,5))
len(shape)
# Out:
# 3
