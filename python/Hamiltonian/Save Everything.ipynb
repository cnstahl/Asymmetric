# %%
import numpy as np
import scipy.linalg as la
import asymmetric as asym
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
L = 9; end = 3; n = 20

weights = asym.get_all_weights(L, end, n, here=True, pauli=True, dense=True,
                               dot_strength=None, field_strength=None,
                               Azero=True, Aplus=True, Amult=False)

# %%
print(weights.shape)
# Out:
# (8, 9, 60)

# %%
for i in weights:
    for j in i:
        plt.plot(j)
    plt.show()

# %%
np.shape([np.array([1,2]),np.array([1,2]),np.array([1,2])])
# Out:
# (3, 2)
