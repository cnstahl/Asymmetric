# %%
% matplotlib inline
import hamiltonian as hm
import matplotlib.pyplot as plt
import numpy as np

# %%
L = 9
end = 3
n = 20
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True, pert_strength=pert_strength)

# %%
end = (int) (n*3)

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightfore9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightback9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

# %%
L = 9
end = 3
n = 20
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=True, dense = True, pert_strength=pert_strength)

# %%
end = (int) (n*3)

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightfore9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightback9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

# %%
L = 9
end = .2
n = 300
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True, pert_strength=pert_strength)

# %%
N = (int) (n*end)

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightfore9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightback9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.ylim(0,1)
plt.show()

# %%
L = 9
end = .2
n = 300
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True, 
                                              pert_strength=pert_strength, finl_pert_strength=0)

# %%
N = (int) (n*end)

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightfore9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightback9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.ylim(0,1)
plt.show()

# %%
L = 9
end = .2
n = 300
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True, 
                                              pert_strength=pert_strength, finl_pert_strength=0)

# %%
N = (int) (n*end)

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightfore9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightback9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.ylim(0,1)
plt.show()

# %%
L = 9
end = .2
n = 300
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True, 
                                              pert_strength=0, finl_pert_strength=0)

# %%
N = (int) (n*end)

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightfore9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightback9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.ylim(0,1)
plt.show()

# %%
L = 9
end = .2
n = 300
pert_strength = 4

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = True)

# %%
N = (int) (n*end)

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightfore9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.semilogy(np.arange(N)/n,weightback9[i,:N], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
# plt.ylim(0,1)
plt.show()

# %%
L = 9
end = 3
n = 20
pert_strength = 2

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = False, pert_strength=pert_strength)

# %%
end = (int) (n*3)

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightfore9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightback9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

# %%
L = 9
end = 3
n = 20
pert_strength = 2

weightfore9, weightback9 = hm.get_all_weights(L, end, n, here=False, dense = False, pert_strength=pert_strength)

# %%
end = (int) (n*3)

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightfore9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()

ax = plt.subplot(111)
for i in range(L):
    ax.plot(np.arange(end)/n,weightback9[i,:end], label = str(i))
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])
ax.legend(bbox_to_anchor=(1.05, 1), loc=2)
plt.ylim(0,1)
plt.show()
