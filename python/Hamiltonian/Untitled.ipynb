# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([5,7,9,11], [.546, .585, .616, .638])
plt.ylabel("Average weight")
plt.xlabel("Length")
plt.savefig("figures/average_weights.pdf")
